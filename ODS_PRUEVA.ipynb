# %% [markdown]
# ---
# title: "ODS PRUEVA "
# author: ""
# format:
#   html:
#     theme: cosmo
#     page-layout: full
#     echo: false
#     css: styles.css
# jupyter: python3
# ---

# %% [markdown]
# # 1. Poner fin a la pobreza en todas sus formas y en todo el mundo
#
# ::: {.panel-tabset}

# %% [markdown]
# ## Meta 1.1

# %% [markdown]
# ```{=html}
# <link rel="stylesheet" href="styles.css">
#
# <details class="ods-acordeon">
#   <summary>Erradicar para todas las personas y en todo el mundo la pobreza extrema</summary>
#   <div>
#     <p>Actualmente se considera que sufren pobreza extrema las personas que viven con menos de 1,25 dólares de los Estados Unidos al día.</p>
#
#     <p style="font-weight:bold; margin-bottom:10px;">ES IMPORTANTE POR:</p>
#
#
#   </div>
# </details>
# ```

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


years = np.arange(2015, 2025)
poverty_rate = [43.2, 41.9, 41.0, 39.5, 41.9, 43.9, 38.0, 36.3, 35.5, 34.2] 

df = pd.DataFrame({'Año': years, 'Tasa de Pobreza (%)': poverty_rate})


plt.figure(figsize=(10, 6))


plt.plot(df['Año'], df['Tasa de Pobreza (%)'], marker='o', linestyle='-', color='#E5243B', linewidth=3, markersize=8, label='Pobreza Laboral')


plt.fill_between(df['Año'], df['Tasa de Pobreza (%)'], 30, color='#E5243B', alpha=0.1)


plt.title('Evolución Simulada de la Pobreza en México (2015-2024)', fontsize=16, fontweight='bold', color='#333')
plt.xlabel('Año', fontsize=12, fontweight='bold')
plt.ylabel('Porcentaje de Población (%)', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(years)
plt.ylim(30, 46)


min_val = min(poverty_rate)
min_year = years[poverty_rate.index(min_val)]
plt.annotate(f'Mínimo: {min_val}%', xy=(min_year, min_val), xytext=(min_year-1, min_val-3),
             arrowprops=dict(facecolor='black', shrink=0.05))

plt.tight_layout()

# %% [markdown]
# ## Meta 1.2

# %% [markdown]
# ```{=html}
# <link rel="stylesheet" href="styles.css">
#
# <details class="ods-acordeon">
#   <summary>META 1.1</summary>
#   <div>
#     <p>Erradicar para todas las personas y en todo el mundo la pobreza extrema </p>
#     <ul>
#       <li>Objetivo breve 1</li>
#       <li>Objetivo breve 2</li>
#     </ul>
#   </div>
# </details>
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
df = pd.read_csv(m.csv)




# Create horizontal bar chart
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(df.iloc[:, 0], df.iloc[:, 2], color='skyblue')
ax.set_xlabel('Cantidad de Metas')
ax.set_ylabel('Objetivo de Desarrollo Sostenible (ODS)')
ax.set_title('Cantidad de Metas por ODS')

# Add labels to each bar
for i, (value, label) in enumerate(zip(df.iloc[:, 2], df.iloc[:, 0])):
    ax.text(value + 0.3, i, str(value), va='center', fontsize=9)

plt.tight_layout()
plt.savefig(output_path)

print("Gráfica de barras horizontales creada y guardada como ods_metas_barplot.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 import matplotlib.pyplot as plt
#       3 import os
# ----> 4 df = pd.read_csv(m.csv)
#       9 # Create horizontal bar chart
#      10 plt.style.use('seaborn-v0_8')
#
# NameError: name 'm' is not defined

# %% [markdown]
# :::

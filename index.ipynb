# %% [raw]
# ---
# title: "ODS UNAM "
# author: ""
# format:
#   html:
#     theme: cosmo
#     page-layout: full
#     echo: false
#     css: styles.css
# jupyter: python3
# ---

# %%
print("HELLO WORLD ")
# Out:
# HELLO WORLD

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         style="background-color: red; color: white; border: none; padding: 10px;">
#   <div class="ods-view-icon">
#     <span class="ods-title">FIN A LA POBREZA</span>
#     <img src="https://cdn-icons-png.flaticon.com/512/9601/9601949.png" alt="ODS Icono" style="width:70px; height:70px;">
#   </div>
#   <div class="ods-view-text">
#     <strong>Fin de la Pobreza</strong>
#     <p style="margin-top: 5px;">Poner fin a la pobreza en todas sus formas en todo el mundo.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         style="background-color: blue; color: white; border: none; padding: 10px;">
#   <div class="ods-view-icon">
#     <span class="ods-title">FIN A LA POBREZA</span>
#     <img src="https://cdn-icons-png.flaticon.com/512/9601/9601949.png" alt="ODS Icono" style="width:70px; height:70px;">
#   </div>
#   <div class="ods-view-text">
#     <strong>Fin de la Pobreza</strong>
#     <p style="margin-top: 5px;">Poner fin a la pobreza en todas sus formas en todo el mundo.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# <link rel="stylesheet" href="styles.css">
# <button class="ods-btn" onclick="window.location.href='ODS_PRUEVA.html';">
# <div class="ods-view-icon">
# <span class="ods-title">FIN A LA POBREZA</span>
# <br></br>
# <img src="https://cdn-icons-png.flaticon.com/512/9601/9601949.png" alt="ODS Icono" style="width:70px; height:70px; filter: invert(1);">
# </div>
# <div class="ods-view-text">
# <strong>Fin de la Pobreza</strong>
# <p style="margin-top: 5px;">Poner fin a la pobreza en todas sus formas en todo el mundo.</p>
# </div>
# </button>

# %% [markdown]
# <link rel="stylesheet" href="styles.css">
# <button class="ods-btn" onclick="window.location.href='ODS_PRUEVA.html';">
# <div class="ods-view-icon">
# <span class="ods-title">FIN A LA POBREZA</span>
# <br></br>
# <img src="https://cdn-icons-png.flaticon.com/512/9601/9601949.png" alt="ODS Icono" style="width:70px; height:70px; filter: invert(1);">
# </div>
# <div class="ods-view-text">
# <strong>Fin de la Pobreza</strong>
# <p style="margin-top: 5px;">Poner fin a la pobreza en todas sus formas en todo el mundo.</p>
# </div>
# </button>

# %% [raw]
# ---
# title: "ODS UNAM "
# author: ""
# format:
#   html:
#     theme: cosmo
#     page-layout: full
#     echo: false
#     css: styles.css
# jupyter: python3
# ---

# %%
print("HELLO WORLD ")
# Out:
# HELLO WORLD

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #E5233D;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/FIN_POBREZA.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #4CA146;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/SALUD_Y_BIENESTAR.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin ">
#   <div class="ods-icon">
#     <img src="/imagenes/EDUCACION_DE_CALIDAD.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

# %% [markdown]
# ```{=html}
# <button class="ods-btn"
#         style="--ods-color: #DDA73A;"
#         onclick="window.location.href='ODS_PRUEVA.html';"
#         aria-label="Fin de la Pobreza">
#   <div class="ods-icon">
#     <img src="/imagenes/CERO_HAMBRE.jpg" alt="Icono Fin de la Pobreza">
#   </div>
#   <div class="ods-text">
#     <strong>Fin de la Pobreza</strong>
#     <p>Poner fin a la pobreza en todas sus formas.</p>
#   </div>
# </button>
# ```

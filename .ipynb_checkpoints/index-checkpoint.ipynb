# %% [raw]
# ---
# title: "Tablero de Indicadores Mundiales"
# author: ""
# format:
#   html:
#     theme: cosmo
#     toc: true
#     toc-location: left
#     page-layout: full
#     # Si quieres reactivarlo, asegúrate de que esté bien escrito:
#     # code-fold: true
#     echo: false
#     css: styles.css
# jupyter: python3
# ---

# %%
print("HELLO WORLD ")
# Out:
# HELLO WORLD

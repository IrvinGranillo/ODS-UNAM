# %% [markdown]
# ---
# title: "ODS PRUEVA "
# author: ""
# format:
#   html:
#     theme: cosmo
#     page-layout: full
#     echo: false
#     css: styles.css
# jupyter: python3
# ---

# %% [markdown]
# <link rel="stylesheet" href="styles.css">
#
# <details class="ods-acordeon">
#   <summary>META 1.1</summary
#   <div>
#     Texto explicativo debajo de la meta 1.1.
#     <ul>
#       <li>Objetivo breve 1</li>
#       <li>Objetivo breve 2</li>
#     </ul>
#   </div>
# </details>
